# %% [markdown]
# ### Exercise 1
#
# Create a DataFrame by reading in the `2019_Yellow_Taxi_Trip_Data.csv` file. Examine the first 5 rows.

# %%
import pandas as pd

# Accessing the GitHub raw file URL with the correct raw URL
data_url = 'https://raw.githubusercontent.com/IST407-707/warm-up-exercise-2-NCodeS5/master/data/2019_Yellow_Taxi_Trip_Data.csv?token=GHSAT0AAAAAACNGYWVX3ADEO23AC64JJMVUZNPKLIA'


# Reading the data into a DataFrame
df = pd.read_csv(data_url)

# Display the first 5 rows of the DataFrame
print(df.head())
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %% [markdown]
# **This dataset provides detailed information about individual taxi rides, including timestamps, distances, locations, fare details, and payment information. Analyzing this data can provide insights into taxi usage patterns, fare distribution, and payment trends.**

# %% [markdown]
# ### Exercise 2
#
# Find the dimensions (number of rows and number of columns) in the data.

# %%
rows, columns = df.shape

# Displaying the dimensions
print(f"Number of Rows: {rows}")
print(f"Number of Columns: {columns}")
# Out:
# Number of Rows: 10000
# Number of Columns: 18

# %% [markdown]
# #### Exercise 3
#
# Calculate summary statistics for the `fare_amount`, `tip_amount`, `tolls_amount`, and `total_amount` columns.

# %%
# Specify the columns for which you want to calculate summary statistics
selected_columns = ['fare_amount', 'tip_amount', 'tolls_amount', 'total_amount']

# Use describe() to calculate summary statistics
summary_stats = df[selected_columns].describe()

# Display the summary statistics
print(summary_stats)
# Out:
#         fare_amount    tip_amount  tolls_amount  total_amount
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean      15.106313      2.634494      0.623447     22.564659
# std       13.954762      3.409800      6.437507     19.209255
# min      -52.000000      0.000000     -6.120000    -65.920000
# 25%        7.000000      0.000000      0.000000     12.375000
# 50%       10.000000      2.000000      0.000000     16.300000
# 75%       16.000000      3.250000      0.000000     22.880000
# max      176.000000     43.000000    612.000000    671.800000

# %% [markdown]
# #### Exercise 4
#
# Count the number of NAs in each column.

# %%
# Count the number of NAs in each column
na_counts = df.isna().sum()

# Display the count of NAs for each column
print(na_counts)
# Out:
# vendorid                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# ratecodeid               0
# store_and_fwd_flag       0
# pulocationid             0
# dolocationid             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# #### Exercise 5
#
# Read the `2019_Yellow_Taxi_Trip_Data.csv` into Pandas. Use a scatter plot matrix (in pandas) to visualize continuous data columns.  That is, drop columns that appear to be ids. Do not visualize date columns.

# %%
# Scatter plot for trip_distance vs fare_amount and total_amount
plt.figure(figsize=(12, 6))

# Scatter plot for trip_distance vs fare_amount
plt.subplot(1, 2, 1)
plt.scatter(df['trip_distance'], df['fare_amount'], alpha=0.5)
plt.title('Scatter Plot: Trip Distance vs Fare Amount')
plt.xlabel('Trip Distance')
plt.ylabel('Fare Amount')
plt.grid(True)

# Scatter plot for trip_distance vs total_amount
plt.subplot(1, 2, 2)
plt.scatter(df['trip_distance'], df['total_amount'], alpha=0.5)
plt.title('Scatter Plot: Trip Distance vs Total Amount')
plt.xlabel('Trip Distance')
plt.ylabel('Total Amount')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Scatter plot for tolls_amount vs fare_amount and total_amount
plt.figure(figsize=(12, 6))

# Scatter plot for tolls_amount vs fare_amount
plt.subplot(1, 2, 1)
plt.scatter(df['tolls_amount'], df['fare_amount'], alpha=0.5)
plt.title('Scatter Plot: Tolls Amount vs Fare Amount')
plt.xlabel('Tolls Amount')
plt.ylabel('Fare Amount')
plt.grid(True)


# Scatter plot for tolls_amount vs total_amount
plt.subplot(1, 2, 2)
plt.scatter(df['tolls_amount'], df['total_amount'], alpha=0.5)
plt.title('Scatter Plot: Tolls Amount vs Total Amount')
plt.xlabel('Tolls Amount')
plt.ylabel('Total Amount')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Scatter plot for mta_tax vs fare_amount and total_amount
plt.figure(figsize=(12, 6))

# Scatter plot for mta_tax vs fare_amount
plt.subplot(1, 2, 1)
plt.scatter(df['mta_tax'], df['fare_amount'], alpha=0.5)
plt.title('Scatter Plot: MTA Tax vs Fare Amount')
plt.xlabel('MTA Tax')
plt.ylabel('Fare Amount')
plt.grid(True)

# Scatter plot for mta_tax vs total_amount
plt.subplot(1, 2, 2)
plt.scatter(df['mta_tax'], df['total_amount'], alpha=0.5)
plt.title('Scatter Plot: MTA Tax vs Total Amount')
plt.xlabel('MTA Tax')
plt.ylabel('Total Amount')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Scatter plot for tip_amount vs fare_amount and total_amount
plt.figure(figsize=(12, 6))

# Scatter plot for tip_amount vs fare_amount
plt.subplot(1, 2, 1)
plt.scatter(df['tip_amount'], df['fare_amount'], alpha=0.5)
plt.title('Scatter Plot: Tip Amount vs Fare Amount')
plt.xlabel('Tip Amount')
plt.ylabel('Fare Amount')
plt.grid(True)

# Scatter plot for tip_amount vs total_amount
plt.subplot(1, 2, 2)
plt.scatter(df['tip_amount'], df['total_amount'], alpha=0.5)
plt.title('Scatter Plot: Tip Amount vs Total Amount')
plt.xlabel('Tip Amount')
plt.ylabel('Total Amount')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Scatter plot for payment_type vs fare_amount and total_amount
plt.figure(figsize=(12, 6))

# Scatter plot for payment_type vs fare_amount
plt.subplot(1, 2, 1)
plt.scatter(df['payment_type'], df['fare_amount'], alpha=0.5)
plt.title('Scatter Plot: Payment Type vs Fare Amount')
plt.xlabel('Payment Type')
plt.ylabel('Fare Amount')
plt.grid(True)

# Scatter plot for payment_type vs total_amount
plt.subplot(1, 2, 2)
plt.scatter(df['payment_type'], df['total_amount'], alpha=0.5)
plt.title('Scatter Plot: Payment Type vs Total Amount')
plt.xlabel('Payment Type')
plt.ylabel('Total Amount')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Exercise 6
#
# Examine the distribution of just the `total_amount` column.  Are there outliers? How can you tell?

# %%
# Box plot for the distribution of total_amount
plt.figure(figsize=(10, 10))
plt.boxplot(df['total_amount'], vert=True, widths=0.7, patch_artist=True, boxprops=dict(facecolor='skyblue', color='black'),
            capprops=dict(color='black'), whiskerprops=dict(color='black'), medianprops=dict(color='black'))
plt.title('Box Plot: Distribution of Total Amount')
plt.xlabel('Total Amount')
plt.show()

# %% [markdown]
# **1. The whiskers typically extend to the minimum and maximum values within a certain range, and points beyond this range are considered outliers.**
#
# **2. In the resulting box plot above , points outside the whiskers are potential outliers.**

# %% [markdown]
# #### Exercise 7
#
# Use a logistic regression classifier and a simple train / test split, find a subset of features that best predict the `fare_amount`.  Do not use `total_amount` or `tip_amount` as features.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Assuming 'df' is the DataFrame containing your data
# Make sure to exclude 'total_amount' and 'tip_amount' from features
features = df.drop(['fare_amount', 'total_amount', 'tip_amount','tpep_pickup_datetime','tpep_dropoff_datetime','store_and_fwd_flag' ], axis=1)
target = df['fare_amount']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Evaluate the model using Mean Squared Error (MSE)
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')

# Print the coefficients of the features
coefficients = pd.Series(model.coef_, index=features.columns)
print('Coefficients:')
print(coefficients)
# Out:
# Mean Squared Error: 30.758824223039095
# Coefficients:
# vendorid                 -2.620627
# passenger_count          -0.000934
# trip_distance             2.635230
# ratecodeid                9.141674
# pulocationid             -0.001210
# dolocationid             -0.004206
# payment_type             -0.790971
# extra                    -1.086414
# mta_tax                   4.396041
# tolls_amount              0.036098
# improvement_surcharge    22.690322
# congestion_surcharge     -0.124445
# dtype: float64

# %% [markdown]
# **Improvement Surcharge (22.69): This feature has the largest positive coefficient, suggesting a relatively strong positive impact on the predicted fare_amount.**

# %% [markdown]
# #### Exercise 8
#
# Do the same thing you did in 7, but use a decision tree classifier.  Which works better? Why do you think that is?

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error


# Make sure to exclude 'total_amount' and 'tip_amount' from features
features = df.drop(['fare_amount', 'total_amount', 'tip_amount','tpep_pickup_datetime','tpep_dropoff_datetime','store_and_fwd_flag'], axis=1)
target = df['fare_amount']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create a decision tree regressor
model_decision_tree = DecisionTreeRegressor(random_state=42)

# Train the model
model_decision_tree.fit(X_train, y_train)

# Make predictions on the test set
predictions_decision_tree = model_decision_tree.predict(X_test)

# Evaluate the model using Mean Squared Error (MSE)
mse_decision_tree = mean_squared_error(y_test, predictions_decision_tree)
print(f'Decision Tree Mean Squared Error: {mse_decision_tree}')
# Out:
# Decision Tree Mean Squared Error: 15.534269824999999

# %% [markdown]
# **Logistic Regression MSE: 30.76**
#
# **Decision Tree MSE: 15.53**
#
# **The Decision Tree model achieved a lower MSE, suggesting that it provided a better fit to the data for predicting the fare_amount. Lower MSE indicates that the predictions from the Decision Tree model were closer to the actual values compared to the Logistic Regression model**
